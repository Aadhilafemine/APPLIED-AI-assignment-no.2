# %% [markdown]
# # GENDER BASED VOICE RECOGNITION

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (2.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.26.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\aathi\anaconda3\envs\applied ai\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pylab as plt
from keras import models
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("voice.csv")
df.head(10)
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# 5  0.132786  0.079557  0.119090  0.067958  0.209592  0.141634   1.932562
# 6  0.150762  0.074463  0.160106  0.092899  0.205718  0.112819   1.530643
# 7  0.160514  0.076767  0.144337  0.110532  0.231962  0.121430   1.397156
# 8  0.142239  0.078018  0.138587  0.088206  0.208587  0.120381   1.099746
# 9  0.134329  0.080350  0.121451  0.075580  0.201957  0.126377   1.190368
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
# 5     8.308895  0.963181  0.738307  ...  0.132786  0.110132  0.017112
# 6     5.987498  0.967573  0.762638  ...  0.150762  0.105945  0.026230
# 7     4.766611  0.959255  0.719858  ...  0.160514  0.093052  0.017758
# 8     4.070284  0.970723  0.770992  ...  0.142239  0.096729  0.017957
# 9     4.787310  0.975246  0.804505  ...  0.134329  0.105881  0.019300
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512   male
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119   male
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274   male
# 5  0.253968  0.298222  0.007812  2.726562  2.718750  0.125160   male
# 6  0.266667  0.479620  0.007812  5.312500  5.304688  0.123992   male
# 7  0.144144  0.301339  0.007812  0.539062  0.531250  0.283937   male
# 8  0.250000  0.336476  0.007812  2.164062  2.156250  0.148272   male
# 9  0.262295  0.340365  0.015625  4.695312  4.679688  0.089920   male
#
# [10 rows x 21 columns]

# %%
label_value_count=df.label.value_counts()
print(label_value_count)
# Out:
# label
# male      1584
# female    1584
# Name: count, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
#  19  modindx   3168 non-null   float64
#  20  label     3168 non-null   object
# dtypes: float64(20), object(1)
# memory usage: 519.9+ KB
# None

# %% [markdown]
# ## Replacing labels for male as 1 and for females as 0

# %%
dict = {'label':{'male':1,'female':0}}      
df.replace(dict,inplace = True)

# %% [markdown]
#  ### after conversion of labels as 0 or 1

# %%
df.head(10)

# %%
df.shape

# %%
x=df.loc[:,df.columns!='label']
y=df.loc[:,'label']

# %% [markdown]
# ## Scaling

# %%
scaler=MinMaxScaler((-1,1))
x=scaler.fit_transform(x)
print(x)

# %% [markdown]
# ## Dividing into Test and Train

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.2, random_state=7)

# %%
from sklearn.svm import SVC # "Support Vector Classifier" 
clf = SVC(kernel='linear') 
clf.fit(x_train, y_train)

# %%
y_pred=clf.predict(x_test)

# %%
print("Accuracy score is",accuracy_score(y_pred,y_test))
